# %%
import pandas as pd
import os
# import logging
from openai import OpenAI
import openai
from tqdm import tqdm
from dotenv import load_dotenv, find_dotenv
from qdrant_client import models, QdrantClient
from qdrant_client.http import models as rest
from qdrant_client.http.models import Record
from sentence_transformers import SentenceTransformer

load_dotenv(find_dotenv())
client = OpenAI(
    api_key=os.getenv('OPENAI_API_KEY'),
)

# Read the CSV dataset
file_path = './datasets/movies_with_embedding.csv'
df = pd.read_csv(file_path) # Add .head(100) if you want to limit the number of rows

df = df.fillna('')

print(str(len(df)) + ' rows')
# Out:
# 39706 rows

# %%
import ast

# Initialize the Qdrant client
qdrant_client = QdrantClient(':memory:')

# Set the collection name and size
collection_name = 'movies'
vector_size = len(ast.literal_eval(df['metadata_vector'][0]))  # Convert string to list and get its length

# Create a collection
qdrant_client.recreate_collection(
    collection_name=collection_name,
    vectors_config={
        'metadata': rest.VectorParams(
            distance=rest.Distance.COSINE,
            size=vector_size,
        ),
    }
)

# Add vectors to the collection
qdrant_client.upsert(
    collection_name=collection_name,
    points=[
        rest.PointStruct(
            id=k,
            vector={
                'metadata': ast.literal_eval(v['metadata_vector']),  # Convert string to list
            },
            payload=v.to_dict(),
        )
        for k, v in df.iterrows()
    ],
)

print(qdrant_client.get_collections())
qdrant_client.count(collection_name=collection_name)
# Out:
# collections=[CollectionDescription(name='movies')]
# CountResult(count=39706)

# %%
# Generate a query embedding and search in Qdrant
def query_qdrant(query, collection_name, vector_name, top_k=20):
    # Creates embedding vector from user query
    completion = openai.embeddings.create(
        input=query,
        model='text-embedding-3-small'  # Be sure to use the same embedding model as the vectors in the collection
    )

    embedded_query = completion.data[0].embedding

    query_results = qdrant_client.search(
        collection_name=collection_name,
        query_vector=(
            vector_name, embedded_query
        ),
        limit=top_k,
    )
    
    return query_results

# %%
# Filter by conditions in Qdrant
def filter_qdrant(adult, date, collection_name, vector_name, top_k=5):
    query_results = qdrant_client.scroll(
        collection_name=collection_name,
        scroll_filter=models.Filter(
            must=[
                models.FieldCondition(
                    key="date",
                    range=models.DatetimeRange(
                        gt=date, # greater than
                        gte=None, # greater than or equal
                        lt=None, # less than
                        lte=None, # less than or equal
                    ),
                ),
                models.FieldCondition(
                    key="adult",
                    match=models.MatchValue(value=adult),
                ),
            ]
        ),
    )
    return query_results

# %%
query_results = filter_qdrant(adult=False, date='2008-02-08T10:49:00Z', collection_name=collection_name, vector_name='metadata')

# print(query_results)

for i, vector in enumerate(query_results[0]):
    print(f"{i + 1}. {vector.payload['title']} ")
# Out:
# 1. My Mom's New Boyfriend (2008)
# 2. My Mom's New Boyfriend (2008)
# 3. My Mom's New Boyfriend (2008)
# 4. My Mom's New Boyfriend (2008)
# 5. Hellboy II: The Golden Army (2008)
# 6. Hellboy II: The Golden Army (2008)
# 7. Hellboy II: The Golden Army (2008)
# 8. Hellboy II: The Golden Army (2008)
# 9. Jumper (2008)
# 10. Jumper (2008)

# %%
# Search for similar vectors and store a result
query_results = query_qdrant('consultant', collection_name=collection_name, vector_name='metadata')

for i, vector in enumerate(query_results):
    print(f"{i + 1}. {vector.payload['title']} {vector.payload['poster_link']} (Score: {round(vector.score, 3)})")
# Out:
# 1. The Specialist (1994) https://images-na.ssl-images-amazon.com/images/M/MV5BYjMwZDMwZTItMTc2MC00NDRlLWI3YmUtNTg0ZmQ3MzdhNDJmXkEyXkFqcGdeQXVyNjQ2MjQ5NzM@._V1
Q@@._V1_UY268_CR4,0,182,268_AL_.jpg (Score: 0.195)
# 13. The Visitor (2007) https://images-na.ssl-images-amazon.com/images/M/MV5BMTIzNTg3NzkzNV5BMl5BanBnXkFtZTcwNzMwMjU2MQ@@._V1_UY268_CR0,0,182,268_AL_.jpg (Score: 0.194)
# 14. The Visitor (2007) https://images-na.ssl-images-amazon.com/images/M/MV5BMTIzNTg3NzkzNV5BMl5BanBnXkFtZTcwNzMwMjU2MQ@@._V1_UY268_CR0,0,182,268_AL_.jpg (Score: 0.194)
# 15. The Visitor (2007) https://images-na.ssl-images-amazon.com/images/M/MV5BMTIzNTg3NzkzNV5BMl5BanBnXkFtZTcwNzMwMjU2MQ@@._V1_UY268_CR0,0,182,268_AL_.jpg (Score: 0.194)
# 16. The Visitor (2007) https://images-na.ssl-images-amazon.com/images/M/MV5BMTIzNTg3NzkzNV5BMl5BanBnXkFtZTcwNzMwMjU2MQ@@._V1_UY268_CR0,0,182,268_AL_.jpg (Score: 0.194)
# 17. The Guru (2002) https://images-na.ssl-images-amazon.com/images/M/MV5BMTg4NzY2MDk0Nl5BMl5BanBnXkFtZTYwNTUxMTg5._V1_UX182_CR0,0,182,268_AL_.jpg (Score: 0.193)
# 18. Doctor at Large (1957) https://images-na.ssl-images-amazon.com/images/M/MV5BMTY1NDc5NTkyM15BMl5BanBnXkFtZTcwMjk0OTAyMQ@@._V1_UY268_CR3,0,182,268_AL_.jpg (Score: 0.193)
# 19. Violence des Ì©changes en milieu tempÌ©rÌ© (2003) https://images-na.ssl-images-amazon.com/images/M/MV5BMzI1N2Q2YzMtYTljMi00YzE5LTljYzktMDVkZjQxYWM3Mzc1XkEyXkFqcGdeQXVyNTY1MDY1NjY@._V1_UY268_CR9,0,182,268_AL_.jpg (Score: 0.192)
# 20. Operation Diplomat (1953) https://images-na.ssl-images-amazon.com/images/M/MV5BYTFiM2QxNzUtYzkwYy00ZDQwLThmMTAtM2Q4YmNiZGM3N2VmXkEyXkFqcGdeQXVyNDY3MzU2MDM@._V1_UX182_CR0,0,182,268_AL_.jpg (Score: 0.192)

# %%
df.head(5)
# Out:
#    imdb_id                               title  \
# 0   114709                    Toy Story (1995)
# 1   113497                      Jumanji (1995)
# 2   113228             Grumpier Old Men (1995)
# 3   114885            Waiting to Exhale (1995)
# 4   113041  Father of the Bride Part II (1995)
#
#                                                                                                                                                                                                                                                                                                                                                                                                        summary  \
# 0                                                                                              Led by Woody, Andy's toys live happily in his room until Andy's birthday brings Buzz Lightyear onto the scene. Afraid of losing his place in Andy's heart, Woody plots against Buzz. But when circumstances separate Buzz and Woody from their owner, the duo eventually learns to put aside their differences.
# 1  When siblings Judy and Peter discover an enchanted board game that opens the door to a magical world, they unwittingly invite Alan -- an adult who's been trapped inside the game for 26 years -- into their living room. Alan's only hope for freedom is to finish the game, which proves risky as all three find themselves running from giant rhinoceroses, evil monkeys and other terrifying creatures.
# 2                                                                      A family wedding reignites the ancient feud between next-door neighbors and fishing buddies John and Max. Meanwhile, a sultry Italian divorcée opens a restaurant at the local bait shop, alarming the locals who worry she'll scare the fish away. But she's less interested in seafood than she is in cooking up a hot time with Max.
# 3                                                                                                                               Cheated on, mistreated and stepped on, the women are holding their breath, waiting for the elusive "good man" to break a string of less-than-stellar lovers. Friends and confidants Vannah, Bernie, Glo and Robin talk it all out, determined to find a better way to breathe.
# 4                                                                               Just when George Banks has recovered from his daughter's wedding, he receives the news that she's pregnant ... and that George's wife, Nina, is expecting too. He was planning on selling their home, but that's a plan that -- like George -- will have to change with the arrival of both a grandchild and a kid of his own.
#
#                    date                                genres  runtime rating  \
# 0  1995-10-30T00:00:00Z  ['Animation', 'Adventure', 'Comedy']       81    8.3
# 1  1995-12-15T00:00:00Z     ['Action', 'Adventure', 'Family']      104    6.9
# 2  1995-12-22T00:00:00Z                 ['Comedy', 'Romance']      101    6.6
# 3  1995-12-22T00:00:00Z        ['Comedy', 'Drama', 'Romance']      127    5.7
# 4  1995-02-10T00:00:00Z       ['Comedy', 'Family', 'Romance']      106    5.9
#
#    votes    budget    revenue language  adult  \
# 0   5415  30000000  373554033  English  False
# 1   2413  65000000  262797249  English  False
# 2     92         0          0  English  False
# 3     34  16000000   81452156  English  False
# 4    173         0   76578911  English  False
#
#                                                           production  \
# 0                                        ['Pixar Animation Studios']
# 1  ['TriStar Pictures', 'Teitler Film', 'Interscope Communications']
# 2                                 ['Warner Bros.', 'Lancaster Gate']
# 3                         ['Twentieth Century Fox Film Corporation']
# 4                   ['Sandollar Productions', 'Touchstone Pictures']
#
#                                                                                                                                                           poster_link  \
# 0   https://images-na.ssl-images-amazon.com/images/M/MV5BMDU2ZWJlMjktMTRhMy00ZTA5LWEzNDgtYmNmZTEwZTViZWJkXkEyXkFqcGdeQXVyNDQ2OTk4MzI@._V1
 0.027745692059397697, -0.01316054817289114, -0.0013270784402266145, -0.00920899212360382, 0.04628804326057434, -0.012109060771763325, -0.010328317061066628, -0.0005363431992009282, 0.0413811057806015, -0.03134109824895859, -0.03898416832089424, 0.015331360511481762, 0.007886153645813465, 0.017411721870303154, 0.0015221124049276114, -0.040453989058732986, 0.04671768471598625, -0.011447641998529434, 0.025529654696583748, 0.04992867633700371, 0.03832840174436569, -0.07195337116718292, 0.0013087056577205658, -0.0007504565292038023, -0.026366321370005608, -0.0023587795440107584, 0.005511827301234007, 0.0014980864943936467, -0.026999475434422493, -0.018010957166552544, -0.0015885370085015893, 0.0022457162849605083, 0.014630368910729885, -0.02482866309583187, -0.057526521384716034, -0.004222908057272434, 0.01900591142475605, 0.042308222502470016, -0.0030046526808291674, 0.018564965575933456, 0.052913542836904526, -0.005342232994735241, 0.0196616780012846, -0.0725865289568901, 0.030074791982769966, -0.016077576205134392, 0.05318489670753479, -0.045722730457782745, 0.04560966417193413, 0.04730561375617981, -0.00988737028092146, -0.06087318807840347, 0.01435901690274477, -0.02781352959573269, -0.01750217191874981, -0.029238125309348106, -0.01720820739865303, 0.025642717257142067, 0.05508435517549515, 0.05110453441739082, -0.0152296032756567, -0.010740997269749641, -0.031748127192258835, 0.017852667719125748, 0.008920680731534958, -0.03190641477704048, 0.02871803380548954, -0.024783438071608543, -0.038464076817035675, -0.007575229741632938, -0.00988737028092146, 0.0003121602348983288, 0.011492867022752762, 0.024172896519303322, 0.0023573662620037794, -0.011758564971387386, -0.02092798426747322, 0.0421951599419117, 0.09289266914129257, 0.008558878675103188, 0.028017044067382812, -0.029464250430464745, 0.017355190590023994, 0.025801006704568863, 0.06738562136888504, -0.038531914353370667, 0.03525308519601822, -0.03256218135356903, -0.017061226069927216, -0.026366321370005608, -0.002302248030900955, 0.02980343997478485, 0.009276829659938812, -0.03794398531317711, -0.002251369645819068, 0.030911458656191826, 0.042896151542663574, 0.011690727435052395, 0.01793181151151657, -0.0031290219631046057, 0.009909982793033123, -0.05390850082039833, 0.005458122584968805, 0.029102448374032974, 0.031318485736846924, -0.022793525829911232, -0.003968515899032354, 0.009259870275855064, -0.032878756523132324, -0.01961645297706127, -0.024172896519303322, 0.03446163982152 ...

# %%
# Format the response as JSON
import json
from datetime import datetime
import locale
import ast

def format_time_to_minutes(minutes_float):
    minutes_int = int(minutes_float)

    hours = minutes_int // 60
    minutes = minutes_int % 60
    
    if hours > 0:
        time_string = f"{hours}h {minutes}m"
    else:
        time_string = f"{minutes}m"
    
    return time_string

def format_as_dollars(number):
    locale.setlocale(locale.LC_ALL, '')

    number = int(number)
    formatted_number = locale.currency(number, grouping=True)
    formatted_number = formatted_number.replace(locale.localeconv()['currency_symbol'], "$")

    return formatted_number

def convert_utc_to_mm_dd_yyyy(utc_datetime_str):
    # Parse the UTC datetime string
    utc_datetime = datetime.strptime(utc_datetime_str, "%Y-%m-%dT%H:%M:%SZ")
    
    # Format the datetime to MM-DD-YYYY
    mm_dd_yyyy_format = utc_datetime.strftime("%m-%d-%Y")
    
    return mm_dd_yyyy_format

# Function to search for similar vectors
def search_movies_in_qdrant(query):
    query_results = query_qdrant(query, collection_name, 'metadata')

    results = []
    
    for i, vector in enumerate(query_results):
        tmp = {
            "rank": i,
            "title": vector.payload["title"],
            "summary": vector.payload["summary"],
            "date": convert_utc_to_mm_dd_yyyy(vector.payload["date"]), # convert this to MM-DD-YYYY format
            "genres": ast.literal_eval(vector.payload["genres"]),
            "runtime": format_time_to_minutes(vector.payload["runtime"]),
            "rating": vector.payload["rating"],
            "votes": int(vector.payload["votes"]),
            "budget": format_as_dollars(vector.payload["budget"]),
            "revenue": format_as_dollars(vector.payload["revenue"]),
            "language": vector.payload["language"],
            "adult": vector.payload["adult"],
            "production": ast.literal_eval(vector.payload["production"]),
            "poster_link": vector.payload["poster_link"]
        }
        results.append(tmp)

    return results

# %%
query = 'scary movies about monsters before year 1998'
response = (search_movies_in_qdrant(query))

json_string = json.dumps(response, indent=2)
print(json_string)
# Out:
# [
#   {
#     "rank": 0,
#     "title": "Little Monsters (1989)",
#     "summary": "A young boy is scared of the monster under his bed. He asks his 6th grade brother to swap rooms for the night as a bet that the monster really exists. Soon the brother becomes friends with the monster and discovers a whole new world of fun and games under his bed where pulling pranks on kids and other monsters is the main attraction",
#     "date": "08-25-1989",
#     "genres": [
#       "Adventure",
#       "Comedy",
#       "Family"
#     ],
#     "runtime": "1h 42m",
#     "rating": 6.1,
#     "votes": 53,
#     "budget": "$7,000,000.00",
#     "revenue": "$793,775.00",
#     "language": "English",
#     "adult": false,
#     "production": [
#       ""
#     ],
#     "poster_link": "https://images-na.ssl-images-amazon.com/images/M/MV5BM2VjOThmNjktNGE1ZS00NWY3LThlMzItOWEyZjMwOGI4ZDNmXkEyXkFqcGdeQXVyMzM4MjM0Nzg@._V1_UX182_CR0,0,182,268_AL_.jpg"
#   },
#   {
#     "rank": 1,
#     "title": "Monster (2008)",
#     "summary": "Two women, aspiring documentary filmmakers, find themselves trapped in a monster-plagued Toyko in 2003.",
#     "date": "01-18-2008",
#     "genres": [
#       "Action",
#       "Horror",
#       "Thriller"
#     ],
#     "runtime": "1h 26m",
#     "rating": 2.1,
#     "votes": 7,
#     "budget": "$0.00",
#     "revenue": "$0.00",
#     "language": "English",
#     "adult": false,
#     "production": [
#       "Asylum",
#       "The"
#     ],
#     "poster_link": "https://images-na.ssl-images-amazon.com/images/M/MV5BMTQ2NjIxNTg5N15BMl5BanBnXkFtZTcwNzE0NzAzOA@@._V1_UY268_CR1,0,182,268_AL_.jpg"
#   },
#   {
#     "rank": 2,
#     "title": "The Monster Club (1981)",
#     "summary": "A writer of horror stories is invited to a \"monster club\" by a mysterious old gentleman. There, three gruesome stories are told to him; between each story some musicians play their songs. In the end, it's recognized he's the greatest monster of all ...",
#     "date": "04-11-1981",
#     "genres": [
#       "Comedy",
#       "Fantasy",
#       "Horror"
#     ],
#     "runtime": "1h 44m",
#     "rating": 5.9,
#     "votes": 21,
#     "budget": "$0.00",
#     "revenue": "$0.00",
#     "language": "French",
#     "adult": false,
#     "production": [
#       "Amicus Productions"
#     ],
#     "poster_link": "https://images-na.ssl-images-amazon.com/images/M/MV5BMTIyMTY5NTg0Ml5BMl5BanBnXkFtZTcwOTI1MDUyMQ@@._V1_UY268_CR4,0,182,268_AL_.jpg"
#   },
#   {
#     "rank": 3,
#     "title": "How to Make a Monster (2001)",
#     "summary": "Video game developer Clayton Software enlists the talents of a misfit group of programmers to develop the scariest computer combat game: EVILUTION. With four weeks to bring the game to market and a million-dollar bonus on the line, they utilize a telemetry suit to render a 3-D version of the onscreen player. But when a power surge gives the hard drive a mind of its own, the suit comes to life to play the game for real and the programming tam find themselves in the middle of a chilling virtual nightmare beyond their wildest imagination.",
#     "date": "10-14-2001",
#     "genres": [
#       "Horror",
#       "Sci-Fi",
#       "Thriller"
#     ],
#     "runtime": "1h 31m",
#     "rating": 4.4,
#     "votes": 11,
#     "budget": "$0.00",
#     "revenue": "$0.00",
#     "language": "French",
#     "adult": false,
#     "production": [
#       ""
#     ],
#     "poster_link": "https://images-na.ssl-images-amazon.com/images/M/MV5BMTIyODQyMDgzN15BMl5BanBnXkFtZTcwNDI5NTkyMQ@@._V1_UY268_CR2,0,182,268_AL_.jpg"
#   },
#   {
#     "rank": 4,
#     "title": "The Monster Squad (1987)",
#     "summary": "Count Dracula adjourns to Earth, accompanied by Frankenstein's Monster, the Wolfman, the Mummy, and the Gillman. The uglies are in search of a powerful amulet that will grant them power to rule the world. Our heroes - the Monster Squad are the only ones daring to stand in their way.",
#     "date": "08-14-1987",
#     "genres": [
#       "Action",
#       "Comedy",
#       "Family"
#     ],
#     "runtime": "1h 22m",
#     "rating": 7.2,
#     "votes": 146,
#     "budget": "$12,000,000.00",
#     "revenue": "$3,769,990.00",
#     "language": "English",
#     "adult": false,
#     "production": [
#       "TriStar Pictures",
#       "Keith Barish Productions",
#       "TAFT Entertainment Pictures",
#       "Home Box Office (HBO)"
#     ],
#     "poster_link": "https://images-na.ssl-images-amazon.com/images/M/MV5BYzhjMzFkMTEtNmEwZi00YWJjLTkzNzctNzUwZWE5NzVmYjdlXkEyXkFqcGdeQXVyNjE5MjUyOTM@._V1_UX182_CR0,0,182,268_AL_.jpg"
#   },
#   {
#     "rank": 5,
#     "title": "Monster House (2006)",
#     "summary": "Monsters under the bed are scary enough, but what happens when an entire house is out to get you? Three teens aim to find out when they go up against a decrepit neighboring home and unlock its frightening secrets.",
#     "date": "07-21-2006",
#     "genres": [
#       "Animation",
#       "Adventure",
#       "Comedy"
#     ],
#     "runtime": "1h 31m",
#     "rating": 6.6,
#     "votes": 912,
#     "budget": "$75,000,000.00",
#     "revenue": "$140,175,006.00",
#     "language": "English",
#     "adult": false,
#     "production": [
#       "Columbia Pictures",
#       "Amblin Entertainment",
#       "Sony Pictures Animation",
#       "Sony Pictures Entertainment",
#       "ImageMovers"
#     ],
#     "poster_link": "https://images-na.ssl-images-amazon.com/images/M/MV5BMTIzNjE1NDg1N15BMl5BanBnXkFtZTcwOTg2NTMzMQ@@._V1_UX182_CR0,0,182,268_AL_.jpg"
#   },
#   {
#     "rank": 6,
#     "title": "Gods and Monsters (1998)",
#     "summary": "It's 1957, and Whale's heyday as the director of \"Frankenstein,\" \"Bride of Frankenstein\" and \"The Invisible Man\" is long behind him. Retired and a semi-recluse, he lives his days accompanied only by images from his past. When his dour housekeeper, Hannah, hires a handsome young gardener, the flamboyant director and simple yard man develop an unlikely friendship, which will change them forever.",
#     "date": "01-21-1998",
#     "genres": [
#       "Biography",
#       "Drama"
#     ],
#     "runtime": "1h 45m",
#     "rating": 7.5,
#     "votes": 82,
#     "budget": "$10,000,000.00",
#     "revenue": "$6,451,628.00",
#     "language": "English",
#     "adult": false,
#     "production": [
#       "Lions Gate Films",
#       "Flashpoint (I)",
#       "Showtime Networks"
#     ],
#     "poster_link": "https://images-na.ssl-images-amazon.com/images/M/MV5BZDczYmY3Y2UtZGQxZi00Zjg1LTk3N2QtMjk4ZGVmYWYwMWQxXkEyXkFqcGdeQXVyNjUwNzk3NDc@._V1_UY268_CR6,0,182,268_AL_.jpg"
#   },
#   {
#     "rank": 7,
#     "title": "Godzilla (1998)",
#     "summary": "When a freighter is viciously attacked in the Pacific Ocean, a team of experts -- including biologist Niko Tatopoulos and scientists Elsie Chapman and Mendel Craven -- concludes that an oversized reptile is the culprit. Before long, the giant lizard is loose in Manhattan, destroying everything within its reach. The team chases the monster to Madison Square Garden, where a brutal battle ensues.",
#     "date": "05-20-1998",
#     "genres": [
#       "Action",
#       "Sci-Fi",
#       "Thriller"
#     ],
#     "runtime": "2h 19m",
#     "rating": 5.3,
#     "votes": 1075,
#     "budget": "$130,000,000.00",
#     "revenue": "$379,014,294.00",
#     "language": "English",
#     "adult": false,
#     "production": [
#       "TriStar Pictures",
#       "Centropolis Film Productions",
#       "Toho Company",
#       "Independent Pictures (II)",
#       "Fried Films"
#     ],
#     "poster_link": "https://images-na.ssl-images-amazon.com/images/M/MV5BNjFlOTI2OGQtMzg0YS00ZGE4LTkwMjEtZDUzYThlOTU5YjQ5XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_UX182_CR0,0,182,268_AL_.jpg"
#   },
#   {
#     "rank": 8,
#     "title": "The Fear (1995)",
#     "summary": "A weekend of 'fear therapy' turns into a nightmare of terror when a mannequin comes to life. Only those with the courage to confront their demons will survive.",
#     "date": "01-20-1995",
#     "genres": [
#       "Horror"
#     ],
#     "runtime": "1h 38m",
#     "rating": 3.4,
#     "votes": 7,
#     "budget": "$0.00",
#     "revenue": "$0.00",
#     "language": "English",
#     "adult": false,
#     "production": [
#       "A-Pix Entertainment",
#       "Devin Entertainment"
#     ],
#     "poster_link": "https://images-na.ssl-images-amazon.com/images/M/MV5BMjE1NzkyNjM2OF5BMl5BanBnXkFtZTcwNzU3MjIyMQ@@._V1_UY268_CR4,0,182,268_AL_.jpg"
#   },
#   {
#     "rank": 9,
#     "title": "Catacombs (1988)",
#     "summary": "A demon is trapped in a monastery. 400 years later a young girl arrives at the monastery to study.",
#     "date": "05-14-1988",
#     "genres": [
#       "Horror"
#     ],
#     "runtime": "1h 24m",
#     "rating": 4.7,
#     "votes": 7,
#     "budget": "$0.00",
#     "revenue": "$0.00",
#     "language": "English",
#     "adult": false,
#     "production": [
#       "Empire Pictures"
#     ],
#     "poster_link": "https://images-na.ssl-images-amazon.com/images/M/MV5BYzhhZjVhMTItODI5Mi00Y2VhLWI5OGYtMDhiODRiNTY1ZjNiXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_UX182_CR0,0,182,268_AL_.jpg"
#   },
#   {
#     "rank": 10,
#     "title": "Nightmares (1983)",
#     "summary": "A collection of short stories. In one a woman who leaves her house late at night to drive to the store while a killer is loose encounters some problems. In the second an arcade whiz kid's obsession with a game leads to deadly consequences. In the third a small town priest loses his faith and decides to leave town, but in the desert is stalked by a mysterious black pick-up truck. In the final story, a family's problem with a rat is larger than they think.",
#     "date": "09-02-1983",
#     "genres": [
#       "Horror",
#       "Sci-Fi"
#     ],
#     "runtime": "1h 39m",
#     "rating": 5.7,
#     "votes": 23,
#     "budget": "$0.00",
#     "revenue": "$6,670,680.00",
#     "language": "English",
#     "adult": false,
#     "production": [
#       "Universal Pictures"
#     ],
#     "poster_link": "https://images-na.ssl-images-amazon.com/images/M/MV5BYTljNjMyYjItNzQxMi00YWE0LTg3ZWYtN2UyZmFkMGE3OTJmXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_UY268_CR0,0,182,268_AL_.jpg"
#   },
#   {
#     "rank": 11,
#     "title": "Phantoms (1998)",
#     "summary": "In the peaceful town of Snowfield, Colorado something evil has wiped out the community. And now, its up to a group of people to stop it, or at least get out of Snowfield alive.",
#     "date": "01-23-1998",
#     "genres": [
#       "Horror",
#       "Sci-Fi",
#       "Thriller"
#     ],
#     "runtime": "1h 31m",
#     "rating": 5.4,
#     "votes": 110,
#     "budget": "$0.00",
#     "revenue": "$5,624,282.00",
#     "language": "English",
#     "adult": false,
#     "production": [
#       "Miramax Films",
#       "Dimension Films"
#     ],
#     "poster_link": "https://images-na.ssl-images-amazon.com/images/M/MV5BNTM2ZmEwZTEtOGI4OC00NDJlLWFhYWUtNGIyMDU5NGE5OTE4XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_UX182_CR0,0,182,268_AL_.jpg"
#   },
#   {
#     "rank": 12,
#     "title": "It Lives Again (1978)",
#     "summary": "The monster child returns - but now there are three!",
#     "date": "05-10-1978",
#     "genres": [
#       "Horror"
#     ],
#     "runtime": "1h 31m",
#     "rating": 5.1,
#     "votes": 17,
#     "budget": "$0.00",
#     "revenue": "$0.00",
#     "language": "English",
#     "adult": false,
#     "production": [
#       "Warner Bros.",
#       "Larco Productions"
#     ],
#     "poster_link": "https://images-na.ssl-images-amazon.com/images/M/MV5BYjVkMTkwNzQtMmMwNy00ZTY3LWFjYzQtMDYwZmRiZTk1YTM3XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_UX182_CR0,0,182,268_AL_.jpg"
#   },
#   {
#     "rank": 13,
#     "title": "How to Make a Monster (1958)",
#     "summary": "When master monster make-up man Pete Dumond is fired by the new bosses of American International studios, he uses his creations to exact revenge.",
#     "date": "07-01-1958",
#     "genres": [
#       "Horror",
#       "Sci-Fi"
#     ],
#     "runtime": "1h 13m",
#     "rating": 5.3,
#     "votes": 5,
#     "budget": "$0.00",
#     "revenue": "$0.00",
#     "language": "English",
#     "adult": false,
#     "production": [
#       "American International Pictures (AIP)"
#     ],
#     "poster_link": "https://images-na.ssl-images-amazon.com/images/M/MV5BMTQ2NTQwMDg4MV5BMl5BanBnXkFtZTgwNzcyMDkwMzE@._V1_UY268_CR3,0,182,268_AL_.jpg"
#   },
#   {
#     "rank": 14,
#     "title": "Night of the Demon (1980)",
#     "summary": "A professor and his students have a grisly encounter with a sasquatchlike creature that prowls the backwoods.",
#     "date": "02-04-1980",
#     "genres": [
#       "Horror"
#     ],
#     "runtime": "1h 37m",
#     "rating": 4.9,
#     "votes": 14,
#     "budget": "$0.00",
#     "revenue": "$0.00",
#     "language": "English",
#     "adult": false,
#     "production": [
#       "Aldan Company"
#     ],
#     "poster_link": "https://images-na.ssl-images-amazon.com/images/M/MV5BMjY5NTY1MDgyN15BMl5BanBnXkFtZTcwNjgyMjM5OA@@._V1_UY268_CR9,0,182,268_AL_.jpg"
#   },
#   {
#     "rank": 15,
#     "title": "The Thing: Terror Takes Shape (1998)",
#     "summary": "An in-depth look at the making of this cult classic",
#     "date": "01-01-1998",
#     "genres": [
#       "Documentary"
#     ],
#     "runtime": "1h 23m",
#     "rating": 7.8,
#     "votes": 9,
#     "budget": "$0.00",
#     "revenue": "$0.00",
#     "language": "English",
#     "adult": false,
#     "production": [
#       "Universal Studios Home Video"
#     ],
#     "poster_link": "https://images-na.ssl-images-amazon.com/images/M/MV5BMTQ1ODY5NTI0Ml5BMl5BanBnXkFtZTcwNzMxMzMyMQ@@._V1_UY268_CR2,0,182,268_AL_.jpg"
#   },
#   {
#     "rank": 16,
#     "title": "The Beast Within (1982)",
#     "summary": "In the beginning of the movie you see a woman getting raped by a man-creature of some sort. The movie takes place years later when the child that was a result of that rape is on the rampage looking for a girl to rape to start the process all over again.",
#     "date": "01-01-1982",
#     "genres": [
#       "Horror"
#     ],
#     "runtime": "1h 38m",
#     "rating": 5.5,
#     "votes": 23,
#     "budget": "$0.00",
#     "revenue": "$0.00",
#     "language": "English",
#     "adult": false,
#     "production": [
#       "Katzka"
#     ],
#     "poster_link": "https://images-na.ssl-images-amazon.com/images/M/MV5BMDAyMjBmMzEtODIxMy00OTBmLTg5ZmItMjg5NGQxNDgxNDYzXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_UX182_CR0,0,182,268_AL_.jpg"
#   },
#   {
#     "rank": 17,
#     "title": "New Nightmare (1994)",
#     "summary": "Freddy's back \u2026 and he's badder than ever! Nancy, the historical nemesis of the man with the satanic snarl and pitchfork fingers, discovers that a new monstrous demon has taken on Freddy's persona. Can Nancy stop this new threat in time to save her son?",
#     "date": "10-13-1994",
#     "genres": [
#       "Fantasy",
#       "Horror",
#       "Mystery"
#     ],
#     "runtime": "1h 52m",
#     "rating": 6.4,
#     "votes": 297,
#     "budget": "$14,000,000.00",
#     "revenue": "$18,090,181.00",
#     "language": "English",
#     "adult": false,
#     "production": [
#       "New Line Cinema"
#     ],
#     "poster_link": "https://images-na.ssl-images-amazon.com/images/M/MV5BM2RmMWIyZDgtY2I4ZS00ZjgwLTlmZTYtY2E2ZmI1Y2IzOGQ4XkEyXkFqcGdeQXVyNTIzOTk5ODM@._V1_UX182_CR0,0,182,268_AL_.jpg"
#   },
#   {
#     "rank": 18,
#     "title": "Monsters, Inc. (2001)",
#     "summary": "James Sullivan and Mike Wazowski are monsters, they earn their living scaring children and are the best in the business... even though they're more afraid of the children than they are of them. When a child accidentally enters their world, James and Mike suddenly find that kids are not to be afraid of and they uncover a conspiracy that could threaten all children across the world.",
#     "date": "11-01-2001",
#     "genres": [
#       "Animation",
#       "Adventure",
#       "Comedy"
#     ],
#     "runtime": "1h 32m",
#     "rating": 8.1,
#     "votes": 6150,
#     "budget": "$115,000,000.00",
#     "revenue": "$562,816,256.00",
#     "language": "English",
#     "adult": false,
#     "production": [
#       "Walt Disney Pictures",
#       "Pixar Animation Studios"
#     ],
#     "poster_link": "https://images-na.ssl-images-amazon.com/images/M/MV5BMTY1NTI0ODUyOF5BMl5BanBnXkFtZTgwNTEyNjQ0MDE@._V1_UX182_CR0,0,182,268_AL_.jpg"
#   },
#   {
#     "rank": 19,
#     "title": "Ghoulies (1984)",
#     "summary": "A young man and his girlfriend move into the man's old mansion home, where he becomes possessed by a need to control ancient demons.",
#     "date": "11-08-1984",
#     "genres": [
#       "Comedy",
#       "Fantasy",
#       "Horror"
#     ],
#     "runtime": "1h 21m",
#     "rating": 4.0,
#     "votes": 58,
#     "budget": "$1,000,000.00",
#     "revenue": "$35,000,000.00",
#     "language": "English",
#     "adult": false,
#     "production": [
#       "Empire Pictures"
#     ],
#     "poster_link": "https://images-na.ssl-images-amazon.com/images/M/MV5BZjIzMzhiOTAtNWM0Yy00MGQ4LWJhNDEtMzUzMjY4OTgyYWM5XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_UX182_CR0,0,182,268_AL_.jpg"
#   }
# ]

# %%
query = 'british movie about two people fall in love'
response = (search_movies_in_qdrant(query))

json_string = json.dumps(response, indent=2)
print(json_string)
# Out:
# [
#   {
#     "rank": 0,
#     "title": "Born Romantic (2000)",
#     "summary": "In modern-day London, three men (Craig Ferguson, Jimi Mistry and David Morrissey) and three women (Olivia Williams, Jane Horrocks and Catherine McCormack) fall in and out of love and back again, to the Greek-chorus accompaniment of two cab drivers, who engage in an ongoing conversation about sex. A winning romantic comedy, Born Romantic is the second feature by British writer-director David Kane of This Year's Love fame.",
#     "date": "09-14-2000",
#     "genres": [
#       "Comedy"
#     ],
#     "runtime": "1h 36m",
#     "rating": 6.5,
#     "votes": 8,
#     "budget": "$0.00",
#     "revenue": "$0.00",
#     "language": "English",
#     "adult": false,
#     "production": [
#       "Kismet Film Company",
#       "British Broadcasting Corporation (BBC)",
#       "Harvest Pictures",
#       "Random Harvest Pictures"
#     ],
#     "poster_link": "https://images-na.ssl-images-amazon.com/images/M/MV5BMTk5ODUxMjIzNV5BMl5BanBnXkFtZTcwMDI1MTMyMQ@@._V1_UY268_CR1,0,182,268_AL_.jpg"
#   },
#   {
#     "rank": 1,
#     "title": "Two Gentlemen Sharing (1969)",
#     "summary": "An insecure Briton and a Briton of Jamaican descent share a London apartment together.",
#     "date": "09-17-1969",
#     "genres": [
#       "Drama",
#       "Romance"
#     ],
#     "runtime": "1h 52m",
#     "rating": 6.1,
#     "votes": 1,
#     "budget": "$0.00",
#     "revenue": "$0.00",
#     "language": "English",
#     "adult": false,
#     "production": [
#       "J. Barry Kulick Production"
#     ],
#     "poster_link": "https://images-na.ssl-images-amazon.com/images/M/MV5BMjA3Mjc1Njc2OV5BMl5BanBnXkFtZTgwOTUxODk1MDE@._V1_UX182_CR0,0,182,268_AL_.jpg"
#   },
#   {
#     "rank": 2,
#     "title": "Two Lovers (2008)",
#     "summary": "A depressed man moves back in with his parents following a recent heartbreak.",
#     "date": "11-19-2008",
#     "genres": [
#       "Drama",
#       "Romance"
#     ],
#     "runtime": "1h 50m",
#     "rating": 7.1,
#     "votes": 157,
#     "budget": "$12,000,000.00",
#     "revenue": "$3,148,182.00",
#     "language": "English",
#     "adult": false,
#     "production": [
#       "2929 Productions",
#       "Wild Bunch",
#       "Tempesta Films"
#     ],
#     "poster_link": "https://images-na.ssl-images-amazon.com/images/M/MV5BMTIzNzIzMzc2Ml5BMl5BanBnXkFtZTcwNDE2MjAyMg@@._V1_UX182_CR0,0,182,268_AL_.jpg"
#   },
#   {
#     "rank": 3,
#     "title": "How to Fall in Love (2012)",
#     "summary": "An accountant, who never quite grew out of his awkward teenage years, finds himself with a dating coach - she happens to be his high school crush as well. Thanks to his coach, he gets a pretty woman he has his sights on for some time, but realizes they are incompatible. Meanwhile, his dating lessons with his teenage crush reawaken old feelings. Not realizing the feelings are mutual, he finds himself unable to act on them due to his fear of being rejected by the one he truly loves.",
#     "date": "07-21-2012",
#     "genres": [
#       "Comedy",
#       "Romance"
#     ],
#     "runtime": "0m",
#     "rating": 6.3,
#     "votes": 20,
#     "budget": "$4,000,000.00",
#     "revenue": "$0.00",
#     "language": "English",
#     "adult": false,
#     "production": [
#       "Annuit Coeptis Entertainment Inc.",
#       "Annuit Coeptis Entertainment II"
#     ],
#     "poster_link": "https://images-na.ssl-images-amazon.com/images/M/MV5BMzc3NjMyNzk2OV5BMl5BanBnXkFtZTgwMTUzODg4MzE@._V1_UX182_CR0,0,182,268_AL_.jpg"
#   },
#   {
#     "rank": 4,
#     "title": "Two English Girls (1971)",
#     "summary": "At the beginning of the 20th century, Claude Roc, a young middle-class Frenchman meets in Paris Ann Brown, a young Englishwoman. They become friends and Ann invites him to spend holidays at the house where she lives with her mother and her sister Muriel, for whom she intends Claude. During these holidays, Claude, Ann and Muriel become very close and he gradually falls in love with Muriel. But both families lay down a one-year-long separation without any contact before agreeing to the marriage. So Claude goes back to Paris when he has many love affairs before sending Muriel a break-off letter...",
#     "date": "11-18-1971",
#     "genres": [
#       "Romance",
#       "Drama"
#     ],
#     "runtime": "2h 10m",
#     "rating": 7.5,
#     "votes": 24,
#     "budget": "$0.00",
#     "revenue": "$0.00",
#     "language": "French",
#     "adult": false,
#     "production": [
#       "Les Films du Carrosse",
#       "Cinetel"
#     ],
#     "poster_link": "https://images-na.ssl-images-amazon.com/images/M/MV5BMTI3MTY3NzIzNF5BMl5BanBnXkFtZTcwMjM2MTUxMQ@@._V1_UX182_CR0,0,182,268_AL_.jpg"
#   },
#   {
#     "rank": 5,
#     "title": "1942: A Love Story (1994)",
#     "summary": "In 1942 the British ruled India, a time when people were either working for the British or rallying for underground meetings and protests against them. Amidst this background, Naren Singh, falls in love with Rajeshwari Pathak. But their romance is not an easy one, for Naren comes from a wealthy, British supporting, family. But Rajeshwari is poor and is fighting against the British.",
#     "date": "04-15-1994",
#     "genres": [
#       "Romance",
#       "Action",
#       "Drama"
#     ],
#     "runtime": "2h 37m",
#     "rating": 7.3,
#     "votes": 5,
#     "budget": "$0.00",
#     "revenue": "$0.00",
#     "language": "",
#     "adult": false,
#     "production": [
#       "Vidhu Vinod Chopra Productions"
#     ],
#     "poster_link": "https://images-na.ssl-images-amazon.com/images/M/MV5BMjcxNTA4NDczNl5BMl5BanBnXkFtZTcwMDI2ODgzMQ@@._V1_UY268_CR3,0,182,268_AL_.jpg"
#   },
#   {
#     "rank": 6,
#     "title": "Falling in Love (1984)",
#     "summary": "During shopping for Christmas, Frank and Molly run into each other. This fleeting short moment will start to change their lives, when they recognize each other months later in the train home and have a good time together. Although both are married and Frank has two little kids, they meet more and more often, their friendship becoming the most precious thing in their lives.",
#     "date": "11-21-1984",
#     "genres": [
#       "Drama",
#       "Romance"
#     ],
#     "runtime": "1h 42m",
#     "rating": 6.5,
#     "votes": 61,
#     "budget": "$0.00",
#     "revenue": "$11,129,057.00",
#     "language": "English",
#     "adult": false,
#     "production": [
#       "Paramount Pictures"
#     ],
#     "poster_link": "https://images-na.ssl-images-amazon.com/images/M/MV5BYmUxNDMyOGQtNTQ1MS00NzhiLWE5ZDUtZGFmMDcyODVmYzU5XkEyXkFqcGdeQXVyMTA0MjU0Ng@@._V1_UX182_CR0,0,182,268_AL_.jpg"
#   },
#   {
#     "rank": 7,
#     "title": "Beloved Enemy (1936)",
#     "summary": "Irish rebels launch an uprising against the British occupation of Ireland in the 1920s. One of the rebellion's leaders and a beautiful aristocratic Englishwoman meet and, despite the enormous class, cultural, political and social differences between them, fall in love.",
#     "date": "12-25-1936",
#     "genres": [
#       "Drama"
#     ],
#     "runtime": "1h 30m",
#     "rating": 6.5,
#     "votes": 2,
#     "budget": "$0.00",
#     "revenue": "$0.00",
#     "language": "English",
#     "adult": false,
#     "production": [
#       "Samuel Goldwyn Company",
#       "The"
#     ],
#     "poster_link": "https://images-na.ssl-images-amazon.com/images/M/MV5BMWFlNmU3M2QtZTdhOS00ZDEzLTlmNzQtNmM1MTEzZmNjZTU4XkEyXkFqcGdeQXVyNjc0MzMzNjA@._V1_UX182_CR0,0,182,268_AL_.jpg"
#   },
#   {
#     "rank": 8,
#     "title": "Dot the I (2003)",
#     "summary": "Young lovers in London are wrapped up in a love triangle that may not be exactly what it seems. Carmen, a beautiful Spanish woman with a tendency to lose her temper at the drop of a hat, is about to be married to Barnaby, a caring, wealthy, but slightly boring Englishman. While out with friends on her 'hen night' she encounters a stranger who suddenly sparks a passion that has been sleeping within her. As her wedding date approaches, she finds herself struggling to put this newcomer out of her mind, but his effect on her keeps growing stronger. What is it that he sees in her, and why does she feel like she's being pushed inevitably into his arms?",
#     "date": "01-18-2003",
#     "genres": [
#       "Drama",
#       "Romance",
#       "Thriller"
#     ],
#     "runtime": "1h 32m",
#     "rating": 6.8,
#     "votes": 32,
#     "budget": "$0.00",
#     "revenue": "$0.00",
#     "language": "English",
#     "adult": false,
#     "production": [
#       "Alquimia Cinema",
#       "Arcane Pictures"
#     ],
#     "poster_link": "https://images-na.ssl-images-amazon.com/images/M/MV5BMTU2MDQ1NjM5N15BMl5BanBnXkFtZTcwNTY5ODcyMQ@@._V1_UX182_CR0,0,182,268_AL_.jpg"
#   },
#   {
#     "rank": 9,
#     "title": "Fall (1997)",
#     "summary": "Writer/director Eric Schaeffer (If Lucy Fell) and Amanda De Cadenet (Four Rooms) steam up the screen with this humorous, provocative and sexy tale of lust and desire that \"examines the surprisingly tender sides of erotic craving\" (MovieMaker). For Michael Shiver (Schaeffer), life as an easy-going cab driver in New York suddenly changes when he picks up supermodel Sarah Easton (De Cadenet) and falls head over heels in love. But Sarah has more than just passion on her mind ? she also has a husband and a glamorous lifestyle that she can't seem to leave behind. Torn between her feelings for Michael and the security of her marriage, Sarah is forced to make a realistic decision about the sacrifices that must be made to be truly and totally in love.",
#     "date": "06-20-1997",
#     "genres": [
#       "Drama",
#       "Romance"
#     ],
#     "runtime": "1h 33m",
#     "rating": 6.0,
#     "votes": 6,
#     "budget": "$0.00",
#     "revenue": "$0.00",
#     "language": "English",
#     "adult": false,
#     "production": [
#       "Terence Michael Productions"
#     ],
#     "poster_link": "https://images-na.ssl-images-amazon.com/images/M/MV5BMzUwMjg1MjcyM15BMl5BanBnXkFtZTcwMTg5NjcyMQ@@._V1_UY268_CR7,0,182,268_AL_.jpg"
#   },
#   {
#     "rank": 10,
#     "title": "The Heart of Me (2002)",
#     "summary": "Drama set in 1930s London with two sisters, Madeleine married to Rickie, and Dinah, who falls in love with him. Rickie and Dinah begin an affair which is to have repercussions throughout all their lives.",
#     "date": "01-01-2002",
#     "genres": [
#       "Drama",
#       "Romance"
#     ],
#     "runtime": "1h 36m",
#     "rating": 6.6,
#     "votes": 5,
#     "budget": "$7,000,000.00",
#     "revenue": "$0.00",
#     "language": "English",
#     "adult": false,
#     "production": [
#       "British Broadcasting Corporation (BBC)"
#     ],
#     "poster_link": "https://images-na.ssl-images-amazon.com/images/M/MV5BMTI4MTMzNjU0MF5BMl5BanBnXkFtZTcwMzQ5NzEzMQ@@._V1_UY268_CR2,0,182,268_AL_.jpg"
#   },
#   {
#     "rank": 11,
#     "title": "Women in Love (1969)",
#     "summary": "Close friends Rupert Birkin and Gerald Crich begin romances with siblings Ursula and Gudrun Brangwen. After the couples wed, they take a joint honeymoon to Switzerland, where things begin happily -- but they become increasingly complicated as the trip continues. Rupert and Ursula are determined to stay faithful to one another, while the aloof Gerald and the eccentric Gudrun turn to infidelity and sexual exploration.",
#     "date": "09-01-1969",
#     "genres": [
#       "Drama",
#       "Romance"
#     ],
#     "runtime": "2h 11m",
#     "rating": 7.6,
#     "votes": 26,
#     "budget": "$1,250,000.00",
#     "revenue": "$0.00",
#     "language": "English",
#     "adult": false,
#     "production": [
#       "Brandywine Productions Ltd."
#     ],
#     "poster_link": "https://images-na.ssl-images-amazon.com/images/M/MV5BMTY4NjA5MDQyOV5BMl5BanBnXkFtZTcwMTM5MTk3NA@@._V1_UX182_CR0,0,182,268_AL_.jpg"
#   },
#   {
#     "rank": 12,
#     "title": "Love and Other Disasters (2006)",
#     "summary": "Flighty Emily \"Jacks\" Jackson works for the British edition of Vogue magazine. Rather than pursue a relationship, Jacks regularly hooks up with her devoted ex-boyfriend, James Wildstone, and lives with Peter Simon, a gay screenwriter. When Jacks meets Argentinian photographer's assistant Paolo Sarmiento, she assumes he is gay and tries to bring him and Peter together, unaware that Paolo is straight and in love with her.",
#     "date": "09-09-2006",
#     "genres": [
#       "Comedy",
#       "Romance"
#     ],
#     "runtime": "1h 31m",
#     "rating": 6.3,
#     "votes": 104,
#     "budget": "$0.00",
#     "revenue": "$0.00",
#     "language": "English",
#     "adult": false,
#     "production": [
#       "Ruby Films",
#       "Skyline Films",
#       "EuropaCorp"
#     ],
#     "poster_link": "https://images-na.ssl-images-amazon.com/images/M/MV5BMTMwOTgwMjg0OV5BMl5BanBnXkFtZTcwNDc3MDMwMg@@._V1_UY268_CR4,0,182,268_AL_.jpg"
#   },
#   {
#     "rank": 13,
#     "title": "Beautiful Thing (1996)",
#     "summary": "A pair of teenage boys growing up in a working-class neighbourhood of Thamesmead, in south-east London, become aware of their homosexuality. While both were vaguely aware they might be gay, neither had ever acted on their impulses. Once they decide that they're attracted to each other, neither is sure just what to do.",
#     "date": "06-21-1996",
#     "genres": [
#       "Comedy",
#       "Drama",
#       "Romance"
#     ],
#     "runtime": "1h 30m",
#     "rating": 7.7,
#     "votes": 76,
#     "budget": "$0.00",
#     "revenue": "$1,500,000.00",
#     "language": "English",
#     "adult": false,
#     "production": [
#       "Channel Four Films",
#       "World Productions"
#     ],
#     "poster_link": "https://images-na.ssl-images-amazon.com/images/M/MV5BYTM4OTllMzYtZmQ0YS00MDU3LTliZDktNjMzYmQ4ZjRjMmFjXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_UX182_CR0,0,182,268_AL_.jpg"
#   },
#   {
#     "rank": 14,
#     "title": "Falling in Love Again (1980)",
#     "summary": "Harry and Sue Lewis met in the 40s as teenagers living in the Bronx. He was an aspiring architect, she was the most beautiful girl in school, and both had a fondness for bran muffins. They fell in love, got married, moved to Los Angeles, and had two kids. While struggling with his midlife crisis, Harry receives an invitation for his high school's reunion back so he takes Sue and their teenage kids on a cross-country car trip back to the Big Apple. Will they see in the Bronx what they expected? Will the good memories from their past help rekindle their fading love? Is it too late to dream?",
#     "date": "11-21-1980",
#     "genres": [
#       "Drama",
#       "Romance"
#     ],
#     "runtime": "1h 43m",
#     "rating": 5.3,
#     "votes": 4,
#     "budget": "$0.00",
#     "revenue": "$0.00",
#     "language": "English",
#     "adult": false,
#     "production": [
#       "O.T.A. Productions"
#     ],
#     "poster_link": "https://images-na.ssl-images-amazon.com/images/M/MV5BMTc2Mjk0NDYzNl5BMl5BanBnXkFtZTcwMzgyNDgxMQ@@._V1_UY268_CR3,0,182,268_AL_.jpg"
#   },
#   {
#     "rank": 15,
#     "title": "A Star for Two (1991)",
#     "summary": "Love between a man and a woman that endures the ravages of time.",
#     "date": "08-10-1991",
#     "genres": [
#       "Drama",
#       "Romance"
#     ],
#     "runtime": "1h 35m",
#     "rating": 7.2,
#     "votes": 0,
#     "budget": "$0.00",
#     "revenue": "$0.00",
#     "language": "Spanish",
#     "adult": false,
#     "production": [
#       ""
#     ],
#     "poster_link": "https://images-na.ssl-images-amazon.com/images/M/MV5BMTM2OTg0NTk2Nl5BMl5BanBnXkFtZTcwMDkyMTM4NA@@._V1_UY268_CR6,0,182,268_AL_.jpg"
#   },
#   {
#     "rank": 16,
#     "title": "Like Crazy (2011)",
#     "summary": "A British college student falls for an American student, only to be separated from him when she's banned from the U.S. after overstaying her visa.",
#     "date": "10-28-2011",
#     "genres": [
#       "Drama",
#       "Romance"
#     ],
#     "runtime": "1h 30m",
#     "rating": 6.7,
#     "votes": 386,
#     "budget": "$250,000.00",
#     "revenue": "$3,542,353.00",
#     "language": "English",
#     "adult": false,
#     "production": [
#       "Paramount Vantage",
#       "Andrea Sperling Productions",
#       "Indian Paintbrush",
#       "Super Crispy Entertainment",
#       "Ascension Productions"
#     ],
#     "poster_link": "https://images-na.ssl-images-amazon.com/images/M/MV5BMjAzOTgyOTU4OF5BMl5BanBnXkFtZTcwNDYxMjcxNg@@._V1_UX182_CR0,0,182,268_AL_.jpg"
#   },
#   {
#     "rank": 17,
#     "title": "Find Love (2006)",
#     "summary": "Find Love is the story of two strangers who aren't looking for love but find it anyway. It is a Twenty-Four hour romance ride that truthfully captures that first feeling of falling for someone.",
#     "date": "01-01-2006",
#     "genres": [
#       "Romance"
#     ],
#     "runtime": "0m",
#     "rating": 6.4,
#     "votes": 0,
#     "budget": "$500,000.00",
#     "revenue": "$0.00",
#     "language": "English",
#     "adult": false,
#     "production": [
#       ""
#     ],
#     "poster_link": "https://images-na.ssl-images-amazon.com/images/M/MV5BMTc4NTgzNDg2N15BMl5BanBnXkFtZTcwMjA5NDIzMQ@@._V1_UY268_CR9,0,182,268_AL_.jpg"
#   },
#   {
#     "rank": 18,
#     "title": "AKA (2002)",
#     "summary": "A story of a disaffected youth's search for love, status, and identity in late 1970s Britain. 18-year old Dean is handsome and bright, but feels hampered by his working-class background and by his family. In order to make something of himself, Dean assumes another identity and manages to enter high society. As he navigates this decadent new world, he meets a host of characters, including David, an older gay man who desires him, and Benjamin, a young hustler from Texas who has also managed to find a place among the aristocracy. Can Dean find love while living a lie? How much is he willing to sacrifice in order to pull off his charade? Presented through three simultaneous frames rather than one.",
#     "date": "01-19-2002",
#     "genres": [
#       "Drama",
#       "Romance"
#     ],
#     "runtime": "2h 3m",
#     "rating": 5.8,
#     "votes": 4,
#     "budget": "$0.00",
#     "revenue": "$0.00",
#     "language": "English",
#     "adult": false,
#     "production": [
#       ""
#     ],
#     "poster_link": "https://images-na.ssl-images-amazon.com/images/M/MV5BMTU1MzU2MTI5OF5BMl5BanBnXkFtZTcwMDk3NjYyMQ@@._V1_UY268_CR1,0,182,268_AL_.jpg"
#   },
#   {
#     "rank": 19,
#     "title": "Love Actually (2003)",
#     "summary": "Follows seemingly unrelated people as their lives begin to intertwine while they fall in \u2013 and out \u2013 of love. Affections languish and develop as Christmas draws near.",
#     "date": "09-07-2003",
#     "genres": [
#       "Comedy",
#       "Drama",
#       "Romance"
#     ],
#     "runtime": "2h 15m",
#     "rating": 7.7,
#     "votes": 1917,
#     "budget": "$40,000,000.00",
#     "revenue": "$244,931,766.00",
#     "language": "English",
#     "adult": false,
#     "production": [
#       "Universal Pictures",
#       "DNA Films",
#       "StudioCanal",
#       "Working Title Films"
#     ],
#     "poster_link": "https://images-na.ssl-images-amazon.com/images/M/MV5BMTY4NjQ5NDc0Nl5BMl5BanBnXkFtZTYwNjk5NDM3._V1_UX182_CR0,0,182,268_AL_.jpg"
#   }
# ]

# %%
query = 'movie about eugenics'
response = (search_movies_in_qdrant(query))

json_string = json.dumps(response, indent=2)
print(json_string)
# Out:
# [
#   {
#     "rank": 0,
#     "title": "Gattaca (1997)",
#     "summary": "Science fiction drama about a future society in the era of indefinite eugenics where humans are set on a life course depending on their DNA. The young Vincent Freeman is born with a condition that would prevent him from space travel, yet he is determined to infiltrate the GATTACA space program.",
#     "date": "09-07-1997",
#     "genres": [
#       "Drama",
#       "Sci-Fi",
#       "Thriller"
#     ],
#     "runtime": "1h 46m",
#     "rating": 7.8,
#     "votes": 1846,
#     "budget": "$36,000,000.00",
#     "revenue": "$12,532,777.00",
#     "language": "English",
#     "adult": false,
#     "production": [
#       "Columbia Pictures",
#       "Jersey Films"
#     ],
#     "poster_link": "https://images-na.ssl-images-amazon.com/images/M/MV5BNDQxOTc0MzMtZmRlOS00OWQ5LWI2ZDctOTAwNmMwOTYxYzlhXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_UX182_CR0,0,182,268_AL_.jpg"
#   },
#   {
#     "rank": 1,
#     "title": "Errors of the Human Body (2012)",
#     "summary": "Canadian scientist Dr Geoff Burton takes up a position at a new institute in wintry Dresden, Germany.  His contribution to their most important project - a human regeneration gene-has the potential to make something miraculous out of a personal tragedy that has haunted him for years.  Errors of the Human Body is about one  man's quest for redemption from his own disturbing past, set within the mysterious world of genetic engineering.",
#     "date": "09-23-2012",
#     "genres": [
#       "Drama",
#       "Sci-Fi",
#       "Thriller"
#     ],
#     "runtime": "1h 42m",
#     "rating": 5.3,
#     "votes": 24,
#     "budget": "$1,500,000.00",
#     "revenue": "$0.00",
#     "language": "English",
#     "adult": false,
#     "production": [
#       "Instinctive Film",
#       "XYZ Films",
#       "High Five Films",
#       "Pandastorm Pictures"
#     ],
#     "poster_link": "https://images-na.ssl-images-amazon.com/images/M/MV5BMjA4MDA2MjkyMF5BMl5BanBnXkFtZTgwMjIwOTIzMTE@._V1_UY268_CR4,0,182,268_AL_.jpg"
#   },
#   {
#     "rank": 2,
#     "title": "Embryo (1976)",
#     "summary": "A scientist doing experiments on a human fetus discovers a method to accelerate the fetus into a mature adult in just a few days. However, the \"adult\" fetus turns into a homicidal psycho and looks for a new formula to prevent her from aging further.",
#     "date": "05-21-1976",
#     "genres": [
#       "Horror",
#       "Sci-Fi"
#     ],
#     "runtime": "1h 44m",
#     "rating": 5.0,
#     "votes": 5,
#     "budget": "$0.00",
#     "revenue": "$0.00",
#     "language": "English",
#     "adult": false,
#     "production": [
#       "Sandy Howard Productions",
#       "Plura Service Company"
#     ],
#     "poster_link": "https://images-na.ssl-images-amazon.com/images/M/MV5BNjcwY2E5Y2MtOGIwMi00NGYzLThhZTMtZjE3MTU3MmI1YzQ4XkEyXkFqcGdeQXVyMTQ2MjQyNDc@._V1_UX182_CR0,0,182,268_AL_.jpg"
#   },
#   {
#     "rank": 3,
#     "title": "The Killing Gene (2007)",
#     "summary": "There is something horribly wrong with the bodies found in the dark city streets. Some are mutilated while others have the Price equation (w\u0394z = Cov (w,z) = \u03b2wzVz) carved into their flesh. Detective Eddie Argo and his new partner Helen Westcott unearth the meaning of the odd equation and realise each victim is being offered a gruesome choice: kill your loved ones, or be killed. Before long it becomes clear that the perpetrator has suffered a similar fate and is now coping by seeking a way to solve this philosophical dilemma.",
#     "date": "05-19-2007",
#     "genres": [
#       "Crime",
#       "Drama",
#       "Horror"
#     ],
#     "runtime": "1h 44m",
#     "rating": 5.7,
#     "votes": 43,
#     "budget": "$0.00",
#     "revenue": "$0.00",
#     "language": "English",
#     "adult": false,
#     "production": [
#       "Ingenious Film Partners",
#       "UK Film Council",
#       "Northern Ireland Film and Television Commission",
#       "Vertigo Films"
#     ],
#     "poster_link": "https://images-na.ssl-images-amazon.com/images/M/MV5BNGZkNDM2ZDItZTliZS00MGQwLWFhY2YtYzY1ZDk5N2U1YTY1XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_UY268_CR3,0,182,268_AL_.jpg"
#   },
#   {
#     "rank": 4,
#     "title": "Forgiving Dr. Mengele (2006)",
#     "summary": "Eva Mozes Kor, who survived Josef Mengele's cruel twin experiments in the Auschwitz concentration camp, shocks other Holocaust survivors when she decides to forgive the perpetrators as a way of self-healing.",
#     "date": "02-24-2006",
#     "genres": [
#       "Documentary"
#     ],
#     "runtime": "1h 22m",
#     "rating": 7.1,
#     "votes": 1,
#     "budget": "$0.00",
#     "revenue": "$0.00",
#     "language": "English",
#     "adult": false,
#     "production": [
#       ""
#     ],
#     "poster_link": "https://images-na.ssl-images-amazon.com/images/M/MV5BMjA2MTg2NzYwMV5BMl5BanBnXkFtZTcwMDk2MDg0MQ@@._V1_UY268_CR8,0,182,268_AL_.jpg"
#   },
#   {
#     "rank": 5,
#     "title": "Speciesism: The Movie (2013)",
#     "summary": "Modern farms are struggling to keep a secret. Most of the animals used for food in the United States are raised in giant, bizarre factories, hidden deep in remote areas of the countryside. Speciesism: The Movie director Mark Devries set out to investigate. The documentary takes viewers on a sometimes funny, sometimes frightening adventure, crawling through the bushes that hide these factories, flying in airplanes above their toxic manure lagoons, and coming face-to-face with their owners.",
#     "date": "09-18-2013",
#     "genres": [
#       "Documentary",
#       "Comedy"
#     ],
#     "runtime": "1h 30m",
#     "rating": 8.4,
#     "votes": 2,
#     "budget": "$0.00",
#     "revenue": "$0.00",
#     "language": "English",
#     "adult": false,
#     "production": [
#       ""
#     ],
#     "poster_link": "https://images-na.ssl-images-amazon.com/images/M/MV5BMTExOTc1MTU3NDVeQTJeQWpwZ15BbWU4MDYxMjcyNTAx._V1_UY268_CR9,0,182,268_AL_.jpg"
#   },
#   {
#     "rank": 6,
#     "title": "Expelled: No Intelligence Allowed (2008)",
#     "summary": "Hosted by Ben Stein, this controversial documentary examines how pro-intelligent design scholars and scientists are often chastised, fired or denied tenured positions by those who believe in Darwin's theory of evolution. Nathan Frankowski's film explores how scientists who believe in God are oppressed and how the acceptance of Darwinism might have played a role in the formation of the Nazi regime.",
#     "date": "04-18-2008",
#     "genres": [
#       "Documentary"
#     ],
#     "runtime": "1h 30m",
#     "rating": 3.7,
#     "votes": 33,
#     "budget": "$3,500,000.00",
#     "revenue": "$7,700,000.00",
#     "language": "English",
#     "adult": false,
#     "production": [
#       "Premise Media Corporation"
#     ],
#     "poster_link": "https://images-na.ssl-images-amazon.com/images/M/MV5BMTY0ODIzMDAxOV5BMl5BanBnXkFtZTcwMTc0MDk2MQ@@._V1_UX182_CR0,0,182,268_AL_.jpg"
#   },
#   {
#     "rank": 7,
#     "title": "Expelled: No Intelligence Allowed (2008)",
#     "summary": "Hosted by Ben Stein, this controversial documentary examines how pro-intelligent design scholars and scientists are often chastised, fired or denied tenured positions by those who believe in Darwin's theory of evolution. Nathan Frankowski's film explores how scientists who believe in God are oppressed and how the acceptance of Darwinism might have played a role in the formation of the Nazi regime.",
#     "date": "04-18-2008",
#     "genres": [
#       "Documentary"
#     ],
#     "runtime": "1h 30m",
#     "rating": 3.7,
#     "votes": 33,
#     "budget": "$3,500,000.00",
#     "revenue": "$7,700,000.00",
#     "language": "English",
#     "adult": false,
#     "production": [
#       "Premise Media Corporation"
#     ],
#     "poster_link": "https://images-na.ssl-images-amazon.com/images/M/MV5BMTY0ODIzMDAxOV5BMl5BanBnXkFtZTcwMTc0MDk2MQ@@._V1_UX182_CR0,0,182,268_AL_.jpg"
#   },
#   {
#     "rank": 8,
#     "title": "Expelled: No Intelligence Allowed (2008)",
#     "summary": "Hosted by Ben Stein, this controversial documentary examines how pro-intelligent design scholars and scientists are often chastised, fired or denied tenured positions by those who believe in Darwin's theory of evolution. Nathan Frankowski's film explores how scientists who believe in God are oppressed and how the acceptance of Darwinism might have played a role in the formation of the Nazi regime.",
#     "date": "04-18-2008",
#     "genres": [
#       "Documentary"
#     ],
#     "runtime": "1h 30m",
#     "rating": 3.7,
#     "votes": 33,
#     "budget": "$3,500,000.00",
#     "revenue": "$7,700,000.00",
#     "language": "English",
#     "adult": false,
#     "production": [
#       "Premise Media Corporation"
#     ],
#     "poster_link": "https://images-na.ssl-images-amazon.com/images/M/MV5BMTY0ODIzMDAxOV5BMl5BanBnXkFtZTcwMTc0MDk2MQ@@._V1_UX182_CR0,0,182,268_AL_.jpg"
#   },
#   {
#     "rank": 9,
#     "title": "Expelled: No Intelligence Allowed (2008)",
#     "summary": "Hosted by Ben Stein, this controversial documentary examines how pro-intelligent design scholars and scientists are often chastised, fired or denied tenured positions by those who believe in Darwin's theory of evolution. Nathan Frankowski's film explores how scientists who believe in God are oppressed and how the acceptance of Darwinism might have played a role in the formation of the Nazi regime.",
#     "date": "04-18-2008",
#     "genres": [
#       "Documentary"
#     ],
#     "runtime": "1h 30m",
#     "rating": 3.7,
#     "votes": 33,
#     "budget": "$3,500,000.00",
#     "revenue": "$7,700,000.00",
#     "language": "English",
#     "adult": false,
#     "production": [
#       "Premise Media Corporation"
#     ],
#     "poster_link": "https://images-na.ssl-images-amazon.com/images/M/MV5BMTY0ODIzMDAxOV5BMl5BanBnXkFtZTcwMTc0MDk2MQ@@._V1_UX182_CR0,0,182,268_AL_.jpg"
#   },
#   {
#     "rank": 10,
#     "title": "Dr. Ehrlich's Magic Bullet (1940)",
#     "summary": "True story of the doctor who considered it was not immoral to search for a drug that would cure syphillis.",
#     "date": "01-03-1940",
#     "genres": [
#       "Biography",
#       "Drama"
#     ],
#     "runtime": "1h 43m",
#     "rating": 7.5,
#     "votes": 9,
#     "budget": "$0.00",
#     "revenue": "$0.00",
#     "language": "English",
#     "adult": false,
#     "production": [
#       "Warner Bros."
#     ],
#     "poster_link": "https://images-na.ssl-images-amazon.com/images/M/MV5BMTY4MjM2OTc4OF5BMl5BanBnXkFtZTcwNDQyMjAyMQ@@._V1_UX182_CR0,0,182,268_AL_.jpg"
#   },
#   {
#     "rank": 11,
#     "title": "Il seme dell'uomo (1969)",
#     "summary": "During a Post-Apocalyptic period in the near future the majority of the European population has been wiped out by some sort of undefined plague. Cino and Dora, a young couple, are rounded up by what constitutes the authorities on an isolated temporary base. They are examined and given antibiotics which will protect them for six months, told to pick out a deserted house to live in the area, and use that time to conceive a child.",
#     "date": "01-01-1969",
#     "genres": [
#       "Drama",
#       "Fantasy",
#       "Romance"
#     ],
#     "runtime": "1h 53m",
#     "rating": 6.7,
#     "votes": 4,
#     "budget": "$0.00",
#     "revenue": "$0.00",
#     "language": "English",
#     "adult": false,
#     "production": [
#       "Polifilm"
#     ],
#     "poster_link": "https://images-na.ssl-images-amazon.com/images/M/MV5BYTllNjNmMjgtZGRmMC00NDAxLWFkZDgtMGYyNWNjNWYwNDM3XkEyXkFqcGdeQXVyMjQ1NTU3Nzg@._V1_UY268_CR3,0,182,268_AL_.jpg"
#   },
#   {
#     "rank": 12,
#     "title": "Extinction: The G.M.O. Chronicles (2011)",
#     "summary": "A Retrovirus, which was conceived as a tool for industrial genetic engineering, has gotten out of control and is spreading rapidly. While it crosses all organisms within our ecological system completely indiscriminately (mixing plant with animal and humans) most plants prove more resistant because of their complex DNA. However, the simple genes of the plants lead humans to become grotesque mutations, in most cases even to death. Within one week, 90% of mankind are either extinct or no longer human. However, a small fraction of the earth?s population remains immune to the virus and must survive in this new and constantly changing ecological system. Tom cellar is one the survivors and on an old military base in the Eifel he has entrenched himself. Further survivors come together and succeed in carving out a life in this new world. But the GMOs - the ?genetically modified organisms? - constantly develop themselves further, and soon the fence of the base offers no more protection.",
#     "date": "01-01-2011",
#     "genres": [
#       "Drama",
#       "Horror"
#     ],
#     "runtime": "1h 54m",
#     "rating": 4.6,
#     "votes": 12,
#     "budget": "$0.00",
#     "revenue": "$0.00",
#     "language": "English",
#     "adult": false,
#     "production": [
#       ""
#     ],
#     "poster_link": "https://images-na.ssl-images-amazon.com/images/M/MV5BMTQ1Njk0Mzc0OF5BMl5BanBnXkFtZTcwMTgwMzg3Ng@@._V1_UY268_CR2,0,182,268_AL_.jpg"
#   },
#   {
#     "rank": 13,
#     "title": "Pathology (2008)",
#     "summary": "Medical student Ted Grey (Milo Ventimiglia) graduates at the top of his class and quickly joins an elite pathology program, whose top students invite him into their circle. There he uncovers a gruesome secret: They play a game in which one tries to commit the perfect, undetectable murder, then the others compete to determine the victim's cause of death.",
#     "date": "04-11-2008",
#     "genres": [
#       "Crime",
#       "Horror",
#       "Thriller"
#     ],
#     "runtime": "1h 35m",
#     "rating": 6.0,
#     "votes": 147,
#     "budget": "$8,000,000.00",
#     "revenue": "$0.00",
#     "language": "English",
#     "adult": false,
#     "production": [
#       "Lakeshore Entertainment",
#       "Metro-Goldwyn-Mayer (MGM)",
#       "Camelot Pictures"
#     ],
#     "poster_link": "https://images-na.ssl-images-amazon.com/images/M/MV5BMTkzMTI1NzYyMV5BMl5BanBnXkFtZTcwODkyMTM2MQ@@._V1_UX182_CR0,0,182,268_AL_.jpg"
#   },
#   {
#     "rank": 14,
#     "title": "Mutants (2009)",
#     "summary": "A nasty virus has spread throughout the human race turning the population into something ...else. After a brief setup (and a messy hit and run) we\u2019re introduced to an ambulance and its four occupants. Sonia (Helene de Fougerolles) and Marco (Francis Renaud) are together and riding with two police officers. Tensions rise between them as they head for a mythical research facility called NOAH that is reportedly infection free and working on a cure, and circumstances lead to Sonia and Marco holing up alone in an abandoned building. She\u2019s pregnant, in love, and apparently immune to the virus\u2026 and she realizes that he\u2019s been infected. He slowly transforms but her love for him refuses to give up on a cure, so she sets out to survive the onslaught of infected, attacks from still-human marauders, and the growing threat from her baby\u2019s daddy.",
#     "date": "05-06-2009",
#     "genres": [
#       "Drama",
#       "Horror",
#       "Sci-Fi"
#     ],
#     "runtime": "1h 25m",
#     "rating": 5.6,
#     "votes": 22,
#     "budget": "$0.00",
#     "revenue": "$0.00",
#     "language": "French",
#     "adult": false,
#     "production": [
#       "Sombrero Films",
#       "Sombrero Productions"
#     ],
#     "poster_link": "https://images-na.ssl-images-amazon.com/images/M/MV5BMTMxMzY2NzAwNl5BMl5BanBnXkFtZTcwNjE5ODI3Mw@@._V1_UY268_CR4,0,182,268_AL_.jpg"
#   },
#   {
#     "rank": 15,
#     "title": "Genocide (1968)",
#     "summary": "A series of separate experiments involving poisonous insects by a pair of disparate characters fuses with a plot about an American H-bomb that's been accidentally dropped\u2014intact\u2014on a remote Japanese island and is the subject of a frenetic search by American officers and shady local characters with ulterior motives of their own. (IMDb)",
#     "date": "11-09-1968",
#     "genres": [
#       "Horror",
#       "Sci-Fi"
#     ],
#     "runtime": "1h 24m",
#     "rating": 4.9,
#     "votes": 2,
#     "budget": "$0.00",
#     "revenue": "$0.00",
#     "language": "Japanese",
#     "adult": false,
#     "production": [
#       "Sh\u00f4chiku Eiga"
#     ],
#     "poster_link": "https://images-na.ssl-images-amazon.com/images/M/MV5BMTE0NTBhYTctMDExYS00NzhhLTg1Y2MtMDY0NjMxYWYyZTUyXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_UY268_CR4,0,182,268_AL_.jpg"
#   },
#   {
#     "rank": 16,
#     "title": "Genocide (1982)",
#     "summary": "The mass murder of Jewish people by the Nazi regime is chronicled, with a warning that anti-Semitism is on the rise and the events of the Holocaust could happen again. The history of European Jewish culture and events before and during the Holocaust are seen in newsreels, photographs, and animated segments. The words of the victims of the era are read, and footage from the liberation os a concentration camp is shown.",
#     "date": "03-14-1982",
#     "genres": [
#       "Documentary",
#       "Drama",
#       "History"
#     ],
#     "runtime": "1h 30m",
#     "rating": 7.1,
#     "votes": 0,
#     "budget": "$0.00",
#     "revenue": "$0.00",
#     "language": "English",
#     "adult": false,
#     "production": [
#       ""
#     ],
#     "poster_link": "https://images-na.ssl-images-amazon.com/images/M/MV5BMjA0NjU5MzE1MF5BMl5BanBnXkFtZTcwOTE4ODM4Mg@@._V1_UX182_CR0,0,182,268_AL_.jpg"
#   },
#   {
#     "rank": 17,
#     "title": "Endgame: Blueprint for Global Enslavement (2007)",
#     "summary": "For the New World Order (NWO), a world government is just the beginning. Once in place they can engage their plan to exterminate 80% of the world's population, while enabling the 'elites' to live forever with the aid of advanced technology. For the first time, crusading filmmaker Alex Jones reveals their secret plan for humanity's extermination: Operation Endgame.",
#     "date": "11-01-2007",
#     "genres": [
#       "Documentary"
#     ],
#     "runtime": "2h 19m",
#     "rating": 7.1,
#     "votes": 13,
#     "budget": "$0.00",
#     "revenue": "$0.00",
#     "language": "English",
#     "adult": false,
#     "production": [
#       ""
#     ],
#     "poster_link": "https://images-na.ssl-images-amazon.com/images/M/MV5BMTUwOTgwMjM2MV5BMl5BanBnXkFtZTcwMjI2MDU1MQ@@._V1_UY268_CR12,0,182,268_AL_.jpg"
#   },
#   {
#     "rank": 18,
#     "title": "Endgame: Blueprint for Global Enslavement (2007)",
#     "summary": "For the New World Order (NWO), a world government is just the beginning. Once in place they can engage their plan to exterminate 80% of the world's population, while enabling the 'elites' to live forever with the aid of advanced technology. For the first time, crusading filmmaker Alex Jones reveals their secret plan for humanity's extermination: Operation Endgame.",
#     "date": "11-01-2007",
#     "genres": [
#       "Documentary"
#     ],
#     "runtime": "2h 19m",
#     "rating": 7.1,
#     "votes": 13,
#     "budget": "$0.00",
#     "revenue": "$0.00",
#     "language": "English",
#     "adult": false,
#     "production": [
#       ""
#     ],
#     "poster_link": "https://images-na.ssl-images-amazon.com/images/M/MV5BMTUwOTgwMjM2MV5BMl5BanBnXkFtZTcwMjI2MDU1MQ@@._V1_UY268_CR12,0,182,268_AL_.jpg"
#   },
#   {
#     "rank": 19,
#     "title": "Endgame: Blueprint for Global Enslavement (2007)",
#     "summary": "For the New World Order (NWO), a world government is just the beginning. Once in place they can engage their plan to exterminate 80% of the world's population, while enabling the 'elites' to live forever with the aid of advanced technology. For the first time, crusading filmmaker Alex Jones reveals their secret plan for humanity's extermination: Operation Endgame.",
#     "date": "11-01-2007",
#     "genres": [
#       "Documentary"
#     ],
#     "runtime": "2h 19m",
#     "rating": 7.1,
#     "votes": 13,
#     "budget": "$0.00",
#     "revenue": "$0.00",
#     "language": "English",
#     "adult": false,
#     "production": [
#       ""
#     ],
#     "poster_link": "https://images-na.ssl-images-amazon.com/images/M/MV5BMTUwOTgwMjM2MV5BMl5BanBnXkFtZTcwMjI2MDU1MQ@@._V1_UY268_CR12,0,182,268_AL_.jpg"
#   }
# ]
